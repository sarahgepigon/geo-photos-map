# %%
import folium

# %%
# Step 1: Create a basic map centered at a lat/lon (e.g., NYC)
m = folium.Map(location=[40.7128, -74.0060], zoom_start=13)

# %%
# Step 2: Add a marker (just 1)
folium.Marker(
    [40.7128, -74.0060],
    popup="Hello from NYC!",
    tooltip="Click me"
).add_to(m)

# %%
# Step 3: Show the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# > NOTE: In a script outside Jupyter (like plain Python), you’d need to save it with m.save("map.html") and open the HTML file

# %%
#test out
m.save("test_map.html")

# %% [markdown]
# - from the [documentation](https://python-visualization.github.io/folium/latest/getting_started.html), it talks about changing the skins with something like `, tiles="cartodb positron")` as a second (or Last?) argument within the Map() function
# - `cartodb positron` is a nicer skin than the default IMO bc it's cleaner
# - i searched documentation for other tilesets `.Map(....,....,tiles = "xyz")` and this was a result: https://python-visualization.github.io/folium/latest/user_guide/raster_layers/tiles.html#Other-tilesets

# %% [markdown]
# > You can also pass any tileset as a url template. Choose one from https://leaflet-extras.github.io/leaflet-providers/preview/ and pass the url and attribution.

# %% [markdown]
# ## map 2

# %%
map_skin2 = folium.Map(location=[40.7128, -74.0060], zoom_start=13, tiles="cartodb positron")

# %%
# Step 2: Add a marker (just 1)
folium.Marker(
    [40.7128, -74.0060],
    popup="Hello from NYC!",
    tooltip="Click me"
).add_to(map_skin2)

# %%
map_skin2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# ## learning to use html links as connection to other map skins

# %% [markdown]
# >Leaflet-providers preview
# >This page shows mini maps for all the layers available in Leaflet-providers.
# >
# >Provider names for leaflet-providers.js
# >Stadia.AlidadeSmooth
# >Plain JavaScript:
# >var Stadia_AlidadeSmooth = L.tileLayer('https://tiles.stadiamaps.com/tiles/alidade_smooth/{z}/{x}/{y}{r}.{ext}', {
# >	minZoom: 0,
# >	maxZoom: 20,
# >	attribution: '&copy; <a href="https://www.stadiamaps.com/" target="_blank">Stadia Maps</a> &copy; <a >href="https://openmaptiles.org/" target="_blank">OpenMapTiles</a> &copy; <a >href="https://www.openstreetmap.org/copyright">OpenStreetMap</a> contributors',
# >	ext: 'png'
# >});
#
# - NOTE: looks like they include an attribution note, so best to keep that in there to give credit!
# - AH! if there is not `attr` param included, it will produce error

# %% [markdown]
# ## map 4

# %%
map_skin4 = folium.Map(
    location=[40.7128, -74.0060], 
    zoom_start=13, 
    tiles="https://{s}.basemaps.cartocdn.com/light_nolabels/{z}/{x}/{y}.png",
    attr='&copy; <a href="https://www.openstreetmap.org/copyright">OpenStreetMap</a> contributors &copy; <a href="https://carto.com/attributions">CARTO</a>'
)

# %%
folium.Map(tiles='https://{s}.tiles.example.com/{z}/{x}/{y}.png', attr='My Data Attribution')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
map_skin4
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# <hr>

# %%
from PIL import Image
import matplotlib.pyplot as plt

# Open and display the image
img = Image.open('bangkok_watarun.png')
plt.imshow(img)
plt.axis('off')  # Hide axes
plt.show()

# %%
# Seattle - Space Needle
space_needle_lat = 47.620422
space_needle_lon = -122.349358
file_seattle = 'https://upload.wikimedia.org/wikipedia/commons/thumb/2/23/Space_Needle_2011-07-04.jpg/960px-Space_Needle_2011-07-04.jpg'
caption_seattle = 'Space Needle'

# New York City - Empire State Building
empire_state_lat = 40.748817
empire_state_lon = -73.985428
file_nyc = 'https://upload.wikimedia.org/wikipedia/commons/thumb/9/91/View_of_Empire_State_Building_from_Rockefeller_Center_New_York_City_dllu_Cropped.jpg/800px-View_of_Empire_State_Building_from_Rockefeller_Center_New_York_City_dllu_Cropped.jpg'
caption_nyc = 'Empire State Building'

# Bangkok - Wat Arun
wat_arun_lat = 13.743500
wat_arun_lon = 100.489000
file_bangkok = 'https://upload.wikimedia.org/wikipedia/commons/thumb/2/2a/%E0%B9%80%E0%B8%88%E0%B8%94%E0%B8%B5%E0%B8%A2%E0%B9%8C%E0%B8%9B%E0%B8%A3%E0%B8%B0%E0%B8%98%E0%B8%B2%E0%B8%99%E0%B8%97%E0%B8%A3%E0%B8%87%E0%B8%9B%E0%B8%A3%E0%B8%B2%E0%B8%87%E0%B8%84%E0%B9%8C%E0%B8%A7%E0%B8%B1%E0%B8%94%E0%B8%AD%E0%B8%A3%E0%B8%B8%E0%B8%932.jpg/2560px-%E0%B9%80%E0%B8%88%E0%B8%94%E0%B8%B5%E0%B8%A2%E0%B9%8C%E0%B8%9B%E0%B8%A3%E0%B8%B0%E0%B8%98%E0%B8%B2%E0%B8%99%E0%B8%97%E0%B8%A3%E0%B8%87%E0%B8%9B%E0%B8%A3%E0%B8%B2%E0%B8%87%E0%B8%84%E0%B9%8C%E0%B8%A7%E0%B8%B1%E0%B8%94%E0%B8%AD%E0%B8%A3%E0%B8%B8%E0%B8%932.jpg'
caption_bangkok = 'Wat Arun'

# %%
import folium, base64
from branca.element import Template, MacroElement

# ------------------------------------------------------------------
# 1.  Minimal data – one row per photo / lat-lon pair
# ------------------------------------------------------------------
data = [
    {"lat": empire_state_lat, "lon": empire_state_lon, "file": file_nyc, "caption": caption_nyc},
    {"lat": space_needle_lat, "lon": space_needle_lon, "file": file_seattle, "caption": caption_seattle},
    {"lat": wat_arun_lat, "lon": wat_arun_lon, "file": file_bangkok, "caption": caption_bangkok}
]
m = folium.Map(location=[empire_state_lat, empire_state_lon], zoom_start=12,
#  tiles="https://{s}.basemaps.cartocdn.com/light_nolabels/{z}/{x}/{y}.png",
tiles ="cartodb positron",
    attr='&copy; <a href="https://www.openstreetmap.org/copyright">OpenStreetMap</a> contributors &copy; <a href="https://carto.com/attributions">CARTO</a>'
)

for row in data:
    img_html = f"""
<div style='text-align:center;'>
  <img src="{row['file']}" style="max-width:50vw;max-height:40vh;border-radius:6px;">
  <p style="margin:4px 0 0;font-weight:600;">{row['caption']}</p>
</div>
"""


    # OPTION A – show the *image* as a Tooltip (hover only, no click)
    tooltip = folium.Tooltip(img_html, sticky=False)

    # OPTION B – same HTML wrapped in a normal Popup (for mobile taps)
    popup  = folium.Popup(img_html, max_width="auto")

    marker = folium.Marker(
        location=[row["lat"], row["lon"]],
        tooltip=tooltip,
        popup=popup,
        icon=folium.Icon(color="orange", icon="camera", prefix="fa")
        ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
m.save("geo_photo_map.html")

# %%
from IPython.display import Image
Image("/work/nyc_empirestatebuilding.png")

# %% [markdown]
# # Parking Lot ideas to pursue (when, why now, and MVP):
# TK TK :)
#
# # Parking Lot / Later wonderings/ to do's:
# - May 29 3:58pm - for zoom start locations ... can it be dynamic, based on where i have my little markers at? that would be cool.
# - May 29 4:00pm - can i customize the markers color and size?
# - May 29 4:00pm - can i make it so if a user just HOVERS over a marker, it will show a photo (mini photo/thumbnail?) and is clickable to another page? showing more info / story about that place?
# - May 29 4:01pm - another consideration is do i want to keep it short and sweet with a hover thing - minimal story info and thumbnail pic, or would it be cute to have a page of its own? or, showing a specific part of a page, like a bookmark within a page? (if it's the last option, it might be a lot of loading and refreshing other photos the user doesn't need to see, so that would hypothetically add to costs)
# - May 29 4:25pm - - sign up to test out different types of basemaps on Stadia Maps (not sure if it'll cost anything if i have say 100 viewers per month on my website)
# - May 29 4:31pm - if i add photos as part of walking tour and i want to highlight what part of a citymap they fall within, i could possibly use this advanced thing! `polygons_from_list_of_points` https://python-visualization.github.io/folium/latest/advanced_guide/polygons_from_list_of_points.html
# - May 29 5:26pm can look into FeatureGroup and LayerControl options for when i want to group and show certain markers! (maybe if i took a photowalk ... here are the things)

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=9608ae32-645f-436f-8177-31030f456fac' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
